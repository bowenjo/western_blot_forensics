# %% [markdown]
# # Western Blot Copy/Paste Descriptor Performance
#
# Measure and display copy/paste detection performance for different descriptors against rotation, scaling, and contrast/brightness transformations.
# Look at performance of the following descriptor methods:
# 1. Histogram of oriented gradients
# 2. Normalized cross correlation

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import wbFingerprintUtils as utils
import wbMomentsFingerprint as wb
from wbPerformancePlots import BlotPerformance
# %matplotlib notebook

# %%
WB = BlotPerformance(rotate_dir = "C:/Users/Joel/Documents/GitHub/westernBlotForensics/wbFingerprints/HOG_testblots_rotate", 
                     scale_dir = "C:/Users/Joel/Documents/GitHub/westernBlotForensics/wbFingerprints/HOG_testblots_scale",
                     adjCon_dir = "C:/Users/Joel/Documents/GitHub/westernBlotForensics/wbFingerprints/HOG_testblots_adjCon")

# %% [markdown]
# ## Performance against rotation
#
# Measure and display copy/paste detection performance for different descriptors against rotation transformations.
# Look at performance of the following descriptor methods:

# %%
WB.rotationPerformance(figsize=(10,8), title="Performance Against Rotation", show_example=True)
# Out:
# <img src="data:image/png;base64,..." width="999.999985098839">
# <img src="data:image/png;base64,..." width="999.999985098839">

# %% [markdown]
# ## Performance against scaling
#
#
# Measure and display copy/paste deetection performance for different descriptors against scaling transformations.
# Look at performance of the following descriptor methods:

# %%
WB.scalingPerformance(figsize=(10,8), title="Performance Against Scaling", show_example=True)
# Out:
# <img src="data:image/png;base64,..." width="999.999985098839">
# <img src="data:image/png;base64,..." width="999.999985098839">

# %% [markdown]
# ## Performance against brightness/contrast adjustments
#
# Measure and display copy/paste detection performance for different descriptors against brightness/contrast adjustments.

# %%
WB.adjContrastPerformance(figsize = (10,8), title="Performance Against Contrast Adjustments", show_example=True)
# Out:
# <img src="data:image/png;base64,..." width="999.999985098839">
# <img src="data:image/png;base64,..." width="999.999985098839">
